# %%
from langchain.agents import create_agent
from IPython.display import Markdown
from dotenv.ipython import load_dotenv
from langchain_openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from langchain.agents import create_agent
#       2 from IPython.display import Markdown
#       3 from dotenv.ipython import load_dotenv
#       4 from langchain_openai import OpenAI
#
# ModuleNotFoundError: No module named 'langchain'

# %%
load_dotenv(override=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 load_dotenv(override=True)
#
# NameError: name 'load_dotenv' is not defined

# %%
agent = create_agent(
    model="openai:gpt-4o", 
    tools=[],
    system_prompt= "You are a helpful assistant"
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 agent = create_agent(
#       2     model="openai:gpt-4o",
#       3     tools=[],
#       4     system_prompt= "You are a helpful assistant"
#
# NameError: name 'create_agent' is not defined

# %%
response = agent.invoke(
    input={
        'messages':[
              {'role':'user', 'content':'My name is Mohamed'}
             ]
            })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response = agent.invoke(
#       2     input={
#       3         'messages':[
#       4               {'role':'user', 'content':'My name is Mohamed'}
#
# NameError: name 'agent' is not defined

# %%
print(display(Markdown(response['messages'][-1].content)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(display(Markdown(response['messages'][-1].content)))
#
# NameError: name 'Markdown' is not defined

# %%
response = agent.invoke(
    input={
        'messages':[
              {'role':'user', 'content':'What is My Name'}
             ]
            }
            )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 response = agent.invoke(
#       2     input={
#       3         'messages':[
#       4               {'role':'user', 'content':'What is My Name'}
#
# NameError: name 'agent' is not defined

# %%
print(display(Markdown(response['messages'][-1].content)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(display(Markdown(response['messages'][-1].content)))
#
# NameError: name 'Markdown' is not defined

# %%
from langchain.agents import create_agent
from langchain_openai import ChatOpenAI
from langchain.messages import HumanMessage
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from langchain.agents import create_agent
#       2 from langchain_openai import ChatOpenAI
#       3 from langchain.messages import HumanMessage
#
# ModuleNotFoundError: No module named 'langchain'

# %%
llm = ChatOpenAI(
    model="gpt-5.2",
    temperature=0.1,
    max_tokens=1000,
    timeout=30
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 llm = ChatOpenAI(
#       2     model="gpt-5.2",
#       3     temperature=0.1,
#       4     max_tokens=1000,
#
# NameError: name 'ChatOpenAI' is not defined

# %%
agent = create_agent(
    model=llm, 
    tools=[],
    system_prompt= "You are a helpful assistant",
    debug=True
    )
response = agent.invoke(input={
    "messages" : [HumanMessage("La ville la plus grande au Maroc")]
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 agent = create_agent(
#       2     model=llm,
#       3     tools=[],
#       4     system_prompt= "You are a helpful assistant",
#
# NameError: name 'create_agent' is not defined

# %%
print(display(Markdown(response['messages'][-1].content)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(display(Markdown(response['messages'][-1].content)))
#
# NameError: name 'Markdown' is not defined

# %%
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from langchain_openai import ChatOpenAI
#       2 from langchain.agents import create_agent
#       3 from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
#
# ModuleNotFoundError: No module named 'langchain_openai'

# %%
basic_model = ChatOpenAI(model="gpt-4o-mini")
advanced_model = ChatOpenAI(model="gpt-4o")

@wrap_model_call
def dynamic_model_selection(request: ModelRequest, handler) -> ModelResponse:
    """Choose model based on conversation complexity."""
    message_count = len(request.state["messages"])
    env=request.runtime.context.get('env','test')
    print(env)
    if env=='prod':
        # Use an advanced model for longer conversations
        model = advanced_model
        print("advanced model selected ....")
    else:
        model = basic_model
        print("basic model selected ....")
    return handler(request.override(model=model))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 basic_model = ChatOpenAI(model="gpt-4o-mini")
#       2 advanced_model = ChatOpenAI(model="gpt-4o")
#       3
#       4 @wrap_model_call
#
# NameError: name 'ChatOpenAI' is not defined

# %%
agent = create_agent(
    model=basic_model,  # Default model
    tools=[],
    middleware=[dynamic_model_selection],
    debug=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 agent = create_agent(
#       2     model=basic_model,  # Default model
#       3     tools=[],
#       4     middleware=[dynamic_model_selection],
#
# NameError: name 'create_agent' is not defined

# %%
agent.invoke(
    input={'messages':[
  HumanMessage('Test 1')
 ]}, context={'env':'test'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 agent.invoke(
#       2     input={'messages':[
#       3   HumanMessage('Test 1')
#       4  ]}, context={'env':'test'})
#
# NameError: name 'agent' is not defined

# %%
agent.invoke(input={'messages':[
  HumanMessage('Test 1')
]}, context={'env':'prod'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 agent.invoke(input={'messages':[
#       2   HumanMessage('Test 1')
#       3 ]}, context={'env':'prod'})
#
# NameError: name 'agent' is not defined

# %%
from langchain.agents import AgentState
from langchain.agents.middleware import AgentMiddleware
from typing import Any
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import ModelRequest, ModelResponse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from langchain.agents import AgentState
#       2 from langchain.agents.middleware import AgentMiddleware
#       3 from typing import Any
#       4 from langgraph.checkpoint.memory import InMemorySaver
#
# ModuleNotFoundError: No module named 'langchain'

# %%
agent = create_agent(
  model="openai:gpt-5.2",
  system_prompt="You are a helpful assistant",
  checkpointer=InMemorySaver()
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 agent = create_agent(
#       2   model="openai:gpt-5.2",
#       3   system_prompt="You are a helpful assistant",
#       4   checkpointer=InMemorySaver()
#
# NameError: name 'create_agent' is not defined

# %%
res=agent.invoke(
  input={'messages':[HumanMessage('My Name is mohamed')]},
  config={'configurable':{'thread_id':1}}
)
print(res['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 res=agent.invoke(
#       2   input={'messages':[HumanMessage('My Name is mohamed')]},
#       3   config={'configurable':{'thread_id':1}}
#       4 )
#
# NameError: name 'agent' is not defined

# %%
res=agent.invoke(
  input={'messages':[HumanMessage('What is my name')]},
  config={'configurable':{'thread_id':1}}
)
print(res['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 res=agent.invoke(
#       2   input={'messages':[HumanMessage('What is my name')]},
#       3   config={'configurable':{'thread_id':1}}
#       4 )
#
# NameError: name 'agent' is not defined

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.postgres import PostgresSaver  

DB_URI = "postgresql://postgres:pwd@localhost:5432/postgres?sslmode=disable"
with PostgresSaver.from_conn_string(DB_URI) as checkpointer:
    checkpointer.setup() # auto create tables in PostgresSql
    agent = create_agent(
        "gpt-5",
        tools=[],
        checkpointer=checkpointer,  
    )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from langchain.agents import create_agent
#       2 from langgraph.checkpoint.postgres import PostgresSaver
#       3
#       4 DB_URI = "postgresql://postgres:pwd@localhost:5432/postgres?sslmode=disable"
#
# ModuleNotFoundError: No module named 'langchain'

# %%
from langchain.tools import tool
from langchain.agents import create_agent
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from langchain.tools import tool
#       2 from langchain.agents import create_agent
#
# ModuleNotFoundError: No module named 'langchain'

# %%
@tool
def search(query: str) -> str:
    """Search for news."""
    print(f'Search tool is called for {query}')
    return {
        'query':query,
        'news': [
            "Le temps est très glacial",
            "les condition météo sont très délicates"
        ]
    }
@tool
def get_weather(location: str) -> str:
    """Get weather information for a location."""
    print(f'Weather tool is called for {location}')
    return f"Weather in {location}: Sunny, 32°C"
@tool
def get_employee_info(name: str) -> str:
    """Get information aboud the given employee name"""
    print(f'get_employee_info tool is called for {name}')
    return {'name' : name, 'salary': 12000, 'job': 'Developper'}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 @tool
#       2 def search(query: str) -> str:
#       3     """Search for news."""
#       4     print(f'Search tool is called for {query}')
#
# NameError: name 'tool' is not defined

# %%
agent = create_agent(
   model=llm, 
   tools=[search, get_weather, get_employee_info]
   )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 agent = create_agent(
#       2    model=llm,
#       3    tools=[search, get_weather, get_employee_info]
#       4    )
#
# NameError: name 'create_agent' is not defined

# %%
response=agent.invoke(input={'messages':[HumanMessage('What is the weather in Marrakech')]})
print(display(Markdown(response['messages'][-1].content)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 response=agent.invoke(input={'messages':[HumanMessage('What is the weather in Marrakech')]})
#       2 print(display(Markdown(response['messages'][-1].content)))
#
# NameError: name 'agent' is not defined

# %%
response=agent.invoke(input={'messages':[HumanMessage('What aye news')]})
print(display(Markdown(response['messages'][-1].content)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 response=agent.invoke(input={'messages':[HumanMessage('What aye news')]})
#       2 print(display(Markdown(response['messages'][-1].content)))
#
# NameError: name 'agent' is not defined

# %%
response=agent.invoke(input={'messages':[
    HumanMessage('Quel est le salaire et le job de Mohamed')
    ]
    }
    )
print(display(Markdown(response['messages'][-1].content)))

# %%
from ddgs import DDGS

@tool
def web_search(query: str, num_results:int=5) -> str:
    """
    Search the web usin DuckDuckGo
    Args:
        query : Search query string
        num_results : Number of results to return (Default=5)
    Returns:
       Formatted search results with titles, descptions and Urls
    """

    try:
        print(f'Search tool is called for {query}')
        ddgs_search = DDGS()
        results=ddgs_search.text(query=query, max_results=num_results, backend="google")
        if not results:
            return f"No results found for {query} "
        formatted_results = [f"Search for {query} : \n"]
        for i, result in enumerate(results,1):
            title = result.get("title","No Title")
            body = result.get("body","No description available")
            href = result.get("href","")
            formatted_results.append( f"{i}. **{title}**. {body}. {href}")
        return formatted_results
    except Exception as e:
        print(str(e))

# %%
agent = create_agent(model=llm, tools=[web_search, get_employee_info, get_weather], debug=True)
resp=agent.invoke(input={'messages':[HumanMessage('Search for python tutorials')]})
print(display(Markdown(resp['messages'][-1].content)))

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.tools import tool
import asyncio
from datetime import datetime
from langchain_tavily import TavilySearch
tavily_search_tool = TavilySearch(max_results=10, search_depth="advanced")

@tool
def search(query: str) -> str:
    """
    Search for general web results
    """
    print("Search Tool invoked")
    return tavily_search_tool.invoke({"query": query})

# %%
model = init_chat_model(model="gpt-4o", model_provider="openai", temperature=0)

agent = create_agent(
    model=model,
    tools=[search],
    system_prompt=f"""You are a helpful assistant that serach the web
                      for information using search tool 
                      today's date is {datetime.now().strftime("%Y-%m-%d")}
                      """,
)

# %%
resp=agent.invoke(input={'messages':[HumanMessage("Quel temps fait-il aujourd'hui à Casablanca")]})
print(display(Markdown(resp['messages'][-1].content)))

# %%
from langchain_experimental.utilities import PythonREPL
python_repl = PythonREPL()
python_repl.run('print(f"la somme de 5 et 6 est {5+9}")')
